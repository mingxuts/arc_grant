# %%
import pandas as pd
import numpy as np
import sys
import os

# %%
# Name of the uni
# uq The University of Queensland
# um The University of Melbourne
# uts
# anu The Australian National University
# uwa The University of Western Australia
# usyd The University of Sydney
# unia The University of Adelaide
# monash Monash University
# unsw The University of New South Wales
PATH = "grants/"
os.listdir(PATH)
# Out:
# ['uq', 'um', 'uts', 'anu', 'uwa', 'usyd', 'unia', 'monash', 'unsw']

# %%
def get_summary(uni_name):
    f_name = PATH + uni_name + "/output.csv"
    use_header = None
    df = pd.read_csv(f_name, header=use_header)
    df[4] = df[4].str.replace(",", "")
    col_names = ["2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019"]
    arr_sum = [np.sum(pd.to_numeric(df[df[5] == i][4])) for i in range(2010, 2020)]
    r1 = pd.Series(arr_sum, index=col_names)
    proj_sum = [len(df.loc[df[5] == i]) for i in range(2010, 2020)]
    r2 = pd.Series(proj_sum, index=col_names)
    return r1, r2


r1, r2 = get_summary("uts")
cict = {"projs":r2, "amount": r1}
pd_um = pd.DataFrame(cict)
print(pd_um)
# Out:
#        amount  projs
# 2010   960371      2
# 2011        0      0
# 2012  1768000      6
# 2013  2535760      5
# 2014  3131220      8
# 2015  1477200      4
# 2016  1235000      3
# 2017  1562000      3
# 2018  2256381      6
# 2019  2181886      5

# %%
unis = os.listdir(PATH)
# Number of Projs
noproj_dict = {}

# Amount of Fundings
amt_dict = {}

for u in unis:
    r1, r2 = get_summary(u)
    #key2 = u + 'proj'
    noproj_dict[u] = r2
    amt_dict[u] = r1

pd_noproj = pd.DataFrame(noproj_dict)
pd_amt = pd.DataFrame(amt_dict)
print(pd_noproj)
print(pd_amt)
# Out:
#       anu  monash  um  unia  unsw  uq  usyd  uts  uwa
# 2010    3       3   4     2     0   1     1    2    1
# 2011    6       6   3     5     1   2     8    0    7
# 2012    4       5   5     4     8   5     4    6    1
# 2013    4       4  10    10     2   8     6    5    3
# 2014    6       5   3     6     4   5     4    8    1
# 2015    5       2   5     1     6   3     5    4    3
# 2016    2       6   6     6     2   5    10    3    2
# 2017    0       3   5     1     5   4     3    3    0
# 2018    4       4   3     3     3   2     5    6    0
# 2019    4       5   2     3     6   3     4    5    2
#           anu   monash       um     unia     unsw       uq     usyd      uts  \
# 2010  1818072   522390  1007000   490858        0   540000   430000   960371
# 2011  1798396  1715000  1153000  2369611   209319   585000  3627984        0
# 2012  1405000  1625000  2264199  1859671  2761387  1923976  1902056  1768000
# 2013  1254000  1215000  4310021  3410000   708000  3299043  1883421  2535760
# 2014  2619689  2829800   873762  2313239  1612398  2333552  1412220  3131220
# 2015  1964500   559800  1861485   359000  2007400  1229200  2142496  1477200
# 2016   642000  2269100  2317800  1891000   830198  1416000  3622647  1235000
# 2017        0   925287  2168500   360000  1813500  1494000  1206500  1562000
# 2018  1390878  1532112  1035752  1668175  1561906   998470  2508091  2256381
# 2019  1521000  2220829   719000  1281000  2455410   961345  1677709  2181886
#
#           uwa
# 2010   542552
# 2011  3228329
# 2012   375000
# 2013   724924
# 2014   320000
# 2015  1419800
# 2016   730500
# 2017        0
# 2018        0
# 2019   906000

# %%
sums = pd_noproj.select_dtypes(pd.np.number).sum().rename('total')
pd_noproj = pd_noproj.append(sums)
pd_noproj = pd_noproj[["anu", "monash", "um", "unia", "unsw", "uq", "usyd", "uwa", "uts"]]
pd_noproj
# Out:
#        anu  monash  um  unia  unsw  uq  usyd  uwa  uts
# 2010     3       3   4     2     0   1     1    1    2
# 2011     6       6   3     5     1   2     8    7    0
# 2012     4       5   5     4     8   5     4    1    6
# 2013     4       4  10    10     2   8     6    3    5
# 2014     6       5   3     6     4   5     4    1    8
# 2015     5       2   5     1     6   3     5    3    4
# 2016     2       6   6     6     2   5    10    2    3
# 2017     0       3   5     1     5   4     3    0    3
# 2018     4       4   3     3     3   2     5    0    6
# 2019     4       5   2     3     6   3     4    2    5
# total   38      43  46    41    37  38    50   20   42

# %%
sums = pd_amt.select_dtypes(pd.np.number).sum().rename('total')
pd_amt = pd_amt.append(sums)
pd_amt = pd_amt[["anu", "monash", "um", "unia", "unsw", "uq", "usyd", "uwa", "uts"]]
pd_amt
# Out:
#             anu    monash        um      unia      unsw        uq      usyd  \
# 2010    1818072    522390   1007000    490858         0    540000    430000
# 2011    1798396   1715000   1153000   2369611    209319    585000   3627984
# 2012    1405000   1625000   2264199   1859671   2761387   1923976   1902056
# 2013    1254000   1215000   4310021   3410000    708000   3299043   1883421
# 2014    2619689   2829800    873762   2313239   1612398   2333552   1412220
# 2015    1964500    559800   1861485    359000   2007400   1229200   2142496
# 2016     642000   2269100   2317800   1891000    830198   1416000   3622647
# 2017          0    925287   2168500    360000   1813500   1494000   1206500
# 2018    1390878   1532112   1035752   1668175   1561906    998470   2508091
# 2019    1521000   2220829    719000   1281000   2455410    961345   1677709
# total  14413535  15414318  17710519  16002554  13959518  14780586  20413124
#
#            uwa       uts
# 2010    542552    960371
# 2011   3228329         0
# 2012    375000   1768000
# 2013    724924   2535760
# 2014    320000   3131220
# 2015   1419800   1477200
# 2016    730500   1235000
# 2017         0   1562000
# 2018         0   2256381
# 2019    906000   2181886
# total  8247105  17107818
